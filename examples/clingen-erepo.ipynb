# %% [markdown]
# ## Annotate ClinVar entries with ACMG scores and GnomAD statistics
#
# Example of GeneBe Python client usage for annotating variants included in the ClinGen Evidence Repository (https://erepo.clinicalgenome.org/evrepo/). This example includes parsing HGVS entities, as this is how variants are represented in the downloaded version of Repository. In the end we will compare automatic ACMG classification with the human classifications from the Repository for each of the ACMG criteria.
#
# This is an example of using Pandas together with GeneBe.

# %%
# Remember to have required packages installed

# !pip install -U genebe
# !pip install tqdm
# !pip install ipywidgets
# !pip install scikit-learn

# %% [markdown]
# ## Download the ClinGen Variants

# %%
import pandas as pd

# download the ClinGen
url = 'https://erepo.clinicalgenome.org/evrepo/api/classifications/all'

erepo = pd.read_csv(url, sep='\t')
print(erepo.shape)

host = 'https://api.genebe.net'
# Out:
# (6105, 20)

# %% [markdown]
# ### Translate HGVS variants
# To proceed we have to convert HGVS variants to chr-pos-ref-alt. This can easily be done using `parse_hgvs`.
#
# Some of the variants are represented in non valid HGVS. They are omited.

# %%
# import genebe as gnb
import genebe as gnb


print('Version:' + gnb.__version__)
# logging.basicConfig(level=logging.INFO)

erepo_subset = erepo.dropna(subset=['#Variation']).copy()
erepo_subset = erepo_subset.reset_index()

variants_hgvs = erepo_subset['#Variation'].tolist()

variants = gnb.parse_variants(variants_hgvs,endpoint_url= f"{host}/cloud/api-public/v1/hgvs",
    batch_size=100)

erepo_subset['variant'] = variants
invalid_hgvs_rows = erepo_subset[erepo_subset['variant'] == '']

count_empty_variant = len(invalid_hgvs_rows)

# Display the count
print(f"Number of rows where 'variant' is an empty string: {count_empty_variant}")
print(invalid_hgvs_rows)
# Out:
# Version:0.0.14
# 100%|██████████| 57/57 [00:23<00:00,  2.45it/s]
# Number of rows where 'variant' is an empty string: 54
#       index                                         #Variation  \
# 143     143            NM_206933.2(USH2A):c.12295-?_14133+?del
# 181     181  NM_000257.4(MYH7):c.2785_2787GAG[2] (p.Glu931del)
# 913     980      NM_000277.3(PAH):c.281_283TCA[1] (p.Ile95del)
# 931     999                 NM_002880.3(RAF1):c.-339_-338AG[1]
# 947    1023   NM_004700.4(KCNQ4):c.803_805CCT[1] (p.Ser269del)
# 1410   1546          NM_001001890.3(RUNX1):c.*2533_*2534TG[10]
# 1412   1550  NM_004360.5(CDH1):c.369_375CCGCCCC[3] (p.His12...
# 1413   1551      NM_004360.5(CDH1):c.436_437TC[1] (p.Pro147fs)
# 1415   1553  NM_004360.5(CDH1):c.32_34TGC[7] (p.Leu14_Leu15...
# 1466   1617    NM_004360.5(CDH1):c.1235_1236TA[3] (p.Ile415fs)
# 1479   1630  NM_004360.5(CDH1):c.2062_2063TG[1] (p.Cys688_G...
# 1485   1636       NM_004360.5(CDH1):c.32_34TGC[6] (p.Leu15dup)
# 1492   1643      NM_004360.5(CDH1):c.692_693TC[2] (p.His233fs)
# 1521   1693       NM_000277.3(PAH):c.578_579CT[1] (p.Leu194fs)
# 1983   2250     NM_004360.5(CDH1):c.2076_2077inv (p.Gly693Ser)
# 2009   2277  NM_001042723.2(RYR1):c.14407_14408inv (p.Phe48...
# 2060   2331       NM_000546.6(TP53):c.85_87AAC[1] (p.Asn30del)
# 2208   2524  NM_000257.4(MYH7):c.2649_2651GAA[1] (p.Lys884del)
# 2398   2732               NM_000527.4(LDLR):c.1061-?_1845+?del
# 2399   2733         NC_000021.9:g.(?_35048832)_(35049298_?)del
# 2402   2736                                      ETHE1, EX4DEL
# 2411   2746                              NM_005465.5:c.1082A>G
# 2889   3235      NC_000011.10:g.(?_108287594)_(108287721_?)del
# 2890   3236       NC_000011.9:g.(?_108137888)_(108225611_?)dup
# 3027   3379      NM_000018.2(ACADVL):c.343delG (p.Glu115Lysfs)
# 3112   3469  NM_000545.6(HNF1A):c.1720_1733delGGCATCCAGCACC...
# 3121   3480     NM_000545.6(HNF1A):c.788_789GT[1] (p.Val264fs)
# 3153   3512                        c.(?_-187)_(190+1_191-1)del
# 3424   3801                         NC_012920.1:m.3902_3908inv
# 3603   3983  NM_001042723.2(RYR1):c.7039_7041GAG[1] (p.Glu2...
# 3744   4135  NM_000018.4(ACADVL):c.1804_1805CT[1] (p.Leu602...
# 3852   4245    NM_005629.4(SLC6A8):c.568_569TG[1] (p.Ala191fs)
# 3855   4248    NM_005629.4(SLC6A8):c.746_747GT[1] (p.Val250fs)
# 3859   4252  NM_005629.4(SLC6A8):c.940_944TTCTT[1] (p.Phe31...
# 3949   4354                                 ITGB3, 11.2-KB DEL
# 4349   4805       NC_000005.9:g.(?_112116481)_(112179829_?)dup
# 4350   4806      NC_000005.10:g.(?_112707312)_(112707902_?)del
# 4351   4807      NC_000005.10:g.(?_112775619)_(112801393_?)del
# 4543   5010                 NM_000527.4(LDLR):c.191-?_940+?del
# 4554   5021                NM_000527.4(LDLR):c.941-?_1060+?del
# 4556   5023                 NM_000527.4(LDLR):c.695-?_817+?del
# 4563   5030               NM_000527.4(LDLR):c.2312-?_2547+?del
# 4585   5052               NM_000527.4(LDLR):c.2390-?_2547+?del
# 4716   5191   NM_000138.4(FBN1):c.7165_7166CT[1] (p.Cys2390fs)
# 4815   5292  NM_005629.4(SLC6A8):c.1000_1002AAC[2] (p.Asn33...
# 4918   5402                               NM_004360.4:c.425A>G
# 5370   5863         NC_000021.9:g.(?_34787801)_(35048958_?)del
# 5372   5865         NC_000021.9:g.(?_34799291)_(35049298_?)del
# 5374   5867         NC_000021.9:g.(?_34880547)_(34880723_?)del
# 5396   5889                 NC_000021.8:g.35304341_36865875del
# 5397   5890         NC_000021.8:g.(?_36231761)_(36231885_?)del
# 5400   5893    GRCh37/hg19 21q22.12(chr21:36164432-36421257)x1
# 5425   5920      NM_000277.3(PAH):c.113_115TCT[1] (p.Phe39del)
# 5457   5953     NM_005629.4(SLC6A8):c.1216TTC[2] (p.Phe408del)
#
#      ClinVar Variation Id Allele Registry Id  \
# 143                177859                  -
# 181                 42934                  -
# 913                   604           CA251535
# 931                 40573           CA177689
# 947                208366                  -
# 1410               339827         CA10653557
# 1412               567576                  -
# 1413               491536                  -
# 1415               142455                  -
# 1466               428622                  -
# 1479               140781                  -
# 1485               220798                  -
# 1492               406615                  -
# 1521               102741           CA229632
# 1983               220300           CA349680
# 2009               478199        CA658658815
# 2060               142158           CA358484
# 2208                36637           CA012790
# 2398               265901                  -
# 2399               650703                  -
# 2402                 2323                  -
# 2411              1296988          CA1483974
# 2889               453341                  -
# 2890               583716                  -
# 3027                 1624           CA220206
# 3112               134513        CA915946722
# 3121               447500                  -
# 3153               250933                  -
# 3424                 9731           CA082749
# 3603               133180                  -
# 3744               203593                  -
# 3852               449366                  -
# 3855               452407                  -
# 3859               633583                  -
# 3949                13563                  -
# 4349               537703                  -
# 4350               429040                  -
# 4351               642643                  -
# 4543               431508                  -
# 4554               417370                  -
# 4556               431513                  -
# 4563               431547                  -
# 4585               226402                  -
# 4716                42420                  -
# 4815               265402                  -
# 4918               584516                  -
# 5370               417476                  -
# 5372               832666                  -
# 5374               833071                  -
# 5396               812913                  -
# 5397              1067688                  -
# 5400              1013200                  -
# 5425               188933                  -
# 5457                11698                  -
#
#                                        HGVS Expressions HGNC Gene Symbol  \
# 143   NM_206933.2:c.12295-?_14133+?del, NM_206933.3(...            USH2A
# 181   NM_000257.4:c.2785_2787GAG[2], NM_000257.4(MYH...             MYH7
# 913   NM_000277.3:c.281_283TCA[1], NM_000277.1:c.284...              PAH
# 931   NM_002880.3:c.-339_-338AG[1], NM_002880.3:c.-3...             RAF1
# 947   NM_004700.4:c.803_805CCT[1], NM_004700.4(KCNQ4...            KCNQ4
# 1410  NM_001001890.3:c.*2533_*2534TG[10], NC_000021....            RUNX1
# 1412  NM_004360.5:c.369_375CCGCCCC[3], NM_004360.5(C...             CDH1
# 1413  NM_004360.5:c.436_437TC[1], NM_004360.5(CDH1):...             CDH1
# 1415  NM_004360.5:c.32_34TGC[7], NM_004360.5(CDH1):c...             CDH1
# 1466  NM_004360.5:c.1235_1236TA[3], NM_004360.5(CDH1...             CDH1
# 1479  NM_004360.5:c.2062_2063TG[1], NM_004360.5(CDH1...             CDH1
# 1485  NM_004360.5:c.32_34TGC[6], NM_004360.5(CDH1):c...             CDH1
# 1492  NM_004360.5:c.692_693TC[2], NM_004360.5(CDH1):...             CDH1
# 1521  NM_000277.3:c.578_579CT[1], NC_000012.12:g.102...              PAH
# 1983  NM_004360.5:c.2076_2077inv, NC_000016.10:g.688...             CDH1
# 2009  NM_001042723.2:c.14407_14408inv, NC_000019.10:...             RYR1
# 2060  NM_000546.6:c.85_87AAC[1], ENST00000269305.9:c...             TP53
# 2208  NM_000257.4:c.2649_2651GAA[1], ENST00000355349...             MYH7
# 2398  NM_000527.4:c.1061-?_1845+?del, NM_000527.4(LD...             LDLR
# 2399         NC_000021.9:g.(?_35048832)_(35049298_?)del            RUNX1
# 2402                                      ETHE1, EX4DEL              NaN
# 2411  NM_005465.5:c.1082A>G, NC_000001.11:g.24355281...             AKT3
# 2889      NC_000011.10:g.(?_108287594)_(108287721_?)del              ATM
# 2890       NC_000011.9:g.(?_108137888)_(108225611_?)dup              NaN
# 3027  NC_000017.11:g.7220924del, CM000679.2:g.722092...           ACADVL
# 3112  NC_000012.12:g.120999592del, CM000674.2:g.1209...            HNF1A
# 3121  NM_000545.6:c.790_791del, NM_000545.8(HNF1A):c...            HNF1A
# 3153                        c.(?_-187)_(190+1_191-1)del             LDLR
# 3424  NC_012920.1:m.3902_3908inv, NC_012920.1:m.3902...           MT-ND1
# 3603  NM_001042723.2:c.7039_7041GAG[1], NM_000540.3(...             RYR1
# 3744  NM_000018.4:c.1804_1805CT[1], NM_000018.4(ACAD...           ACADVL
# 3852  NM_005629.4:c.568_569TG[1], NM_005629.4(SLC6A8...           SLC6A8
# 3855  NM_005629.4:c.746_747GT[1], NM_005629.4(SLC6A8...           SLC6A8
# 3859  NM_005629.4:c.940_944TTCTT[1], NM_005629.4(SLC...           SLC6A8
# 3949   NG_008332.2:g.48605_58661del, ITGB3, 11.2-KB DEL            ITGB3
# 4349       NC_000005.9:g.(?_112116481)_(112179829_?)dup              APC
# 4350      NC_000005.10:g.(?_112707312)_(112707902_?)del              APC
# 4351      NC_000005.10:g.(?_112775619)_(112801393_?)del              APC
# 4543                 NM_000527.4(LDLR):c.191-?_940+?del             LDLR
# 4554                NM_000527.4(LDLR):c.941-?_1060+?del             LDLR
# 4556                 NM_000527.4(LDLR):c.695-?_817+?del             LDLR
# 4563               NM_000527.4(LDLR):c.2312-?_2547+?del             LDLR
# 4585               NM_000527.4(LDLR):c.2390-?_2547+?del             LDLR
# 4716  NM_000138.4:c.7165_7166CT[1], NM_000138.4:c.71...             FBN1
# 4815  NM_005629.4:c.1000_1002AAC[2], NM_005629.4(SLC...           SLC6A8
# 4918                               NM_004360.4:c.425A>G              NaN
# 5370         NC_000021.9:g.(?_34787801)_(35048958_?)del              NaN
# 5372         NC_000021.9:g.(?_34799291)_(35049298_?)del              NaN
# 5374         NC_000021.9:g.(?_34880547)_(34880723_?)del              NaN
# 5396                 NC_000021.8:g.35304341_36865875del              NaN
# 5397         NC_000021.8:g.(?_36231761)_(36231885_?)del              NaN
# 5400    GRCh37/hg19 21q22.12(chr21:36164432-36421257)x1              NaN
# 5425  NM_000277.3:c.113_115TCT[1], NM_000277.3(PAH):...              PAH
# 5457  NM_005629.4:c.1222_1224del, NM_005629.4(SLC6A8...           SLC6A8
#
#                                                 Disease       Mondo Id  \
# 143                                      Usher syndrome  MONDO:0019501
# 181                         hypertrophic cardiomyopathy  MONDO:0005045
# 913                                     phenylketonuria  MONDO:0009861
# 931                                           RASopathy  MONDO:0021060
# 947                       nonsyndromic genetic deafness  MONDO:0019497
# 1410  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 1412  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 1413  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 1415  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 1466  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 1479  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 1485  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 1492  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 1521                                    phenylketonuria  MONDO:0009861
# 1983  CDH1-related diffuse gastric and lobular breas...  MONDO:0007648
# 2009               malignant hyperthermia of anesthesia  MONDO:0018493
# 2060                             Li-Fraumeni syndrome 1  MONDO:0007903
# 2208                        hypertrophic cardiomyopathy  MONDO:0005045
# 2398                     hypercholesterolemia, familial  MONDO:0007750
# 2399  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 2402                        ethylmalonic encephalopathy  MONDO:0011229
# 2411  overgrowth syndrome and/or cerebral malformati...  MONDO:0016054
# 2889                           hereditary breast cancer  MONDO:0016419
# 2890                           hereditary breast cancer  MONDO:0016419
# 3027  very long chain acyl-CoA dehydrogenase deficiency  MONDO:0008723
# 3112                                 monogenic diabetes  MONDO:0015967
# 3121                                 monogenic diabetes  MONDO:0015967
# 3153                     hypercholesterolemia, familial  MONDO:0007750
# 3424                              mitochondrial disease  MONDO:0044970
# 3603       malignant hyperthermia, susceptibility to, 1  MONDO:0007783
# 3744  very long chain acyl-CoA dehydrogenase deficiency  MONDO:0008723
# 3852                    creatine transporter deficiency  MONDO:0010305
# 3855                    creatine transporter deficiency  MONDO:0010305
# 3859                    creatine transporter deficiency  MONDO:0010305
# 3949                           Glanzmann thrombasthenia  MONDO:0100326
# 4349                   familial adenomatous polyposis 1  MONDO:0021056
# 4350                   familial adenomatous polyposis 1  MONDO:0021056
# 4351                   familial adenomatous polyposis 1  MONDO:0021056
# 4543                     hypercholesterolemia, familial  MONDO:0007750
# 4554                     hypercholesterolemia, familial  MONDO:0007750
# 4556                     hypercholesterolemia, familial  MONDO:0007750
# 4563                     hypercholesterolemia, familial  MONDO:0007750
# 4585                     hypercholesterolemia, familial  MONDO:0007750
# 4716                                    Marfan syndrome  MONDO:0007947
# 4815                    creatine transporter deficiency  MONDO:0010305
# 4918  CDH1-related diffuse gastric and lobular breas...  MONDO:0100488
# 5370  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 5372  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 5374  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 5396  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 5397  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 5400  hereditary thrombocytopenia and hematologic ca...  MONDO:0011071
# 5425                                    phenylketonuria  MONDO:0009861
# 5457                    creatine transporter deficiency  MONDO:0010305
#
#                           Mode of Inheritance               Assertion  ...  \
# 143           Autosomal recessive inheritance       Likely Pathogenic  ...
# 181            Autosomal dominant inheritance       Likely Pathogenic  ...
# 913           Autosomal recessive inheritance              Pathogenic  ...
# 931            Autosomal dominant inheritance                  Benign  ...
# 947            Autosomal dominant inheritance              Pathogenic  ...
# 1410           Autosomal dominant inheritance                  Benign  ...
# 1412           Autosomal dominant inheritance              Pathogenic  ...
# 1413           Autosomal dominant inheritance              Pathogenic  ...
# 1415           Autosomal dominant inheritance           Likely Benign  ...
# 1466           Autosomal dominant inheritance              Pathogenic  ...
# 1479           Autosomal dominant inheritance              Pathogenic  ...
# 1485           Autosomal dominant inheritance           Likely Benign  ...
# 1492           Autosomal dominant inheritance              Pathogenic  ...
# 1521          Autosomal recessive inheritance              Pathogenic  ...
# 1983           Autosomal dominant inheritance           Likely Benign  ...
# 2009           Autosomal dominant inheritance  Uncertain Significance  ...
# 2060           Autosomal dominant inheritance  Uncertain Significance  ...
# 2208           Autosomal dominant inheritance  Uncertain Significance  ...
# 2398                 Semidominant inheritance              Pathogenic  ...
# 2399           Autosomal dominant inheritance              Pathogenic  ...
# 2402          Autosomal recessive inheritance              Pathogenic  ...
# 2411  Autosomal dominant inheritance (mosaic)           Likely Benign  ...
# 2889           Autosomal dominant inheritance              Pathogenic  ...
# 2890           Autosomal dominant inheritance       Likely Pathogenic  ...
# 3027          Autosomal recessive inheritance              Pathogenic  ...
# 3112           Autosomal dominant inheritance       Likely Pathogenic  ...
# 3121           Autosomal dominant inheritance       Likely Pathogenic  ...
# 3153                 Semidominant inheritance              Pathogenic  ...
# 3424                Mitochondrial inheritance       Likely Pathogenic  ...
# 3603           Autosomal dominant inheritance       Likely Pathogenic  ...
# 3744          Autosomal recessive inheritance       Likely Pathogenic  ...
# 3852                     X-linked inheritance              Pathogenic  ...
# 3855                     X-linked inheritance       Likely Pathogenic  ...
# 3859                     X-linked inheritance       Likely Pathogenic  ...
# 3949          Autosomal recessive inheritance              Pathogenic  ...
# 4349           Autosomal dominant inheritance  Uncertain Significance  ...
# 4350           Autosomal dominant inheritance              Pathogenic  ...
# 4351           Autosomal dominant inheritance       Likely Pathogenic  ...
# 4543                 Semidominant inheritance       Likely Pathogenic  ...
# 4554                 Semidominant inheritance              Pathogenic  ...
# 4556                 Semidominant inheritance       Likely Pathogenic  ...
# 4563                 Semidominant inheritance       Likely Pathogenic  ...
# 4585                 Semidominant inheritance              Pathogenic  ...
# 4716           Autosomal dominant inheritance              Pathogenic  ...
# 4815                     X-linked inheritance              Pathogenic  ...
# 4918           Autosomal dominant inheritance  Uncertain Significance  ...
# 5370           Autosomal dominant inheritance              Pathogenic  ...
# 5372           Autosomal dominant inheritance              Pathogenic  ...
# 5374           Autosomal dominant inheritance              Pathogenic  ...
# 5396           Autosomal dominant inheritance              Pathogenic  ...
# 5397           Autosomal dominant inheritance              Pathogenic  ...
# 5400           Autosomal dominant inheritance       Likely Pathogenic  ...
# 5425          Autosomal recessive inheritance              Pathogenic  ...
# 5457                     X-linked inheritance              Pathogenic  ...
#
#                               Summary of interpretation  \
# 143   The variant NM_206933.3:c.12295-?_14133+?del i...
# 181   The NM_000257.3(MYH7):c.2791_2793delGAG (p.Glu...
# 913   This variant was documented in 8 patients diag...
# 931   The c.-339_-338delAG variant in RAF1 is classi...
# 947   The c.803_805CCT[1] (aka c.806_808del) variant...
# 1410  The NM_001001890.3:c.*2533_*2534TG[10] (or c.*...
# 1412  The c.369_375CCGCCCC[3] (p.His128Profs*42) var...
# 1413  The c.438_439delTC p.(Pro147Trpfs*20) variant ...
# 1415  The c.32_34TGC[7] (p.Leu14_Leu15dup) variant r...
# 1466  The c.1235_1236TA[3] (p.Ile415fs) variant is p...
# 1479  The c.2064_2065delTG (p.Cys688Terfs) variant i...
# 1485  The c.32_34TGC[6] (p.Leu15dup), also referred ...
# 1492  The c.696_697delTC p.(His233fs) variant is pre...
# 1521  The c.578_579del PAH variant has been identifi...
# 1983  The c.2076_2077inv (p.Gly693Ser) variant has b...
# 2009  This pathogenicity assessment is relevant only...
# 2060  This variant has been observed in 2-7 60+ year...
# 2208  The c.2652_2654delGAA (p.Lys884del) variant in...
# 2398  The NM_000527.4(LDLR):c.1061-?_1845+?del varia...
# 2399  Deletion of exons 1-3 including the initiation...
# 2402  The ETHE1 EX4DEL mutation is a predicted null ...
# 2411  The c.1082A>G (NM_005465.7) variant in AKT3 is...
# 2889  The ATM EX27del variant is absent from gnomAD ...
# 2890  The ATM EX16_60dup variant is presumed to be a...
# 3027  The NM_000018.4(ACADVL): c.343del (p.Glu115Lys...
# 3112  The c.1720_1733del variant in the HNF1 homeobo...
# 3121  The c.790_791del variant in the  HNF1 homeobox...
# 3153  The NM_000527.5 (LDLR):c.(?_-187)_(190+1_191-1...
# 3424  The m.3902_3908inv (p.DLA199GKV) variant in MT...
# 3603  This pathogenicity assessment is relevant only...
# 3744  The c.1806_1807del (p.Leu602_Cys603insTer) var...
# 3852  The NM_005629.4:c.570_571del (p.Ala191GlnfsTer...
# 3855  The NM_005629.4:c.746_747delGT (p.Val250LeufsT...
# 3859  The NM_005629.4:c.940_944delTTCTT (p.Phe315Leu...
# 3949  The 11.2kb deletion in ITGB3 (NC_000017.11:g.4...
# 4349  The NC_000005.9:g.(?_112116481)_(112179829_?)d...
# 4350  The NC_000005.10:g.(?_112707312)_(112707902_?)...
# 4351  The NC_000005.10:g.(?_112775619)_(112801393_?)...
# 4543  The NM_000527.4(LDLR):c.191-?_940+?del variant...
# 4554  The NM_000527.4(LDLR):c.941-?_1060+?del varian...
# 4556  The NM_000527.4(LDLR):c.695-?_817+?del variant...
# 4563  The NM_000527.4(LDLR):c.2312-?_2547+?del varia...
# 4585  The NM_000527.5(LDLR):c.2390-?_2547+?del varia...
# 4716  The NM_00138 c.7165_7166, is a frameshift vari...
# 4815  The NM_005629.4:c.1000_1002delAAC variant in S...
# 4918  The c.425T>C (NM_004360.5) variant in CDH1 is ...
# 5370  NC_000021.9:g.(?_34787801)_(35048958_?)del res...
# 5372  This is a full gene deletion and is classified...
# 5374  NC_000021.9:g.(?_34880547)_(34880723_?)del cau...
# 5396  This variant is completely absent from all pop...
# 5397  This variant is a frameshift variant resulting...
# 5400  GRCh37/hg19 21q22.12(chr21:36164432-36421257)x...
# 5425  This c.113_115TCTdel (p.Phe39del) variant is a...
# 5457  The NM_005629.4:c.1222_1224del variant in SLC6...
#
#                                         PubMed Articles  \
# 143                                            26969326
# 181                                                 NaN
# 913   29316886, 19292873, 25894915, 26666653, 243686...
# 931                                                 NaN
# 947                                            34316018
# 1410                                                NaN
# 1412                                                NaN
# 1413                                                NaN
# 1415                                                NaN
# 1466                                                NaN
# 1479                                                NaN
# 1485                                                NaN
# 1492                                                NaN
# 1521                                           26666653
# 1983                                                NaN
# 2009                                                NaN
# 2060                                                NaN
# 2208                                                NaN
# 2398                                                NaN
# 2399                                                NaN
# 2402  16183799, 20978941, 21048580, 20528888, 161837...
# 2411                                                NaN
# 2889                                                NaN
# 2890                                                NaN
# 3027                                                NaN
# 3112                                                NaN
# 3121                                                NaN
# 3153                                                NaN
# 3424                                                NaN
# 3603                                                NaN
# 3744                                                NaN
# 3852                                                NaN
# 3855                                                NaN
# 3859                                                NaN
# 3949                                                NaN
# 4349                                                NaN
# 4350                                                NaN
# 4351                                                NaN
# 4543                                                NaN
# 4554                                                NaN
# 4556                                                NaN
# 4563                                                NaN
# 4585                                                NaN
# 4716                                                NaN
# 4815                                                NaN
# 4918                                                NaN
# 5370                                                NaN
# 5372                                                NaN
# 5374                                                NaN
# 5396                                                NaN
# 5397             10508512, 11830488, 10508512, 11830488
# 5400                                                NaN
# 5425  16256386, 23500595, 12655550, 29102225, 265427...
# 5457                                                NaN
#
#                                            Expert Panel  \
# 143                                   Hearing Loss VCEP
# 181                                 Cardiomyopathy VCEP
# 913                                Phenylketonuria VCEP
# 931                                      RASopathy VCEP
# 947                                   Hearing Loss VCEP
# 1410                            Myeloid Malignancy VCEP
# 1412                                          CDH1 VCEP
# 1413                                          CDH1 VCEP
# 1415                                          CDH1 VCEP
# 1466                                          CDH1 VCEP
# 1479                                          CDH1 VCEP
# 1485                                          CDH1 VCEP
# 1492                                          CDH1 VCEP
# 1521                               Phenylketonuria VCEP
# 1983                                          CDH1 VCEP
# 2009         Malignant Hyperthermia Susceptibility VCEP
# 2060                                          TP53 VCEP
# 2208                                Cardiomyopathy VCEP
# 2398                 Familial Hypercholesterolemia VCEP
# 2399                            Myeloid Malignancy VCEP
# 2402                        Mitochondrial Diseases VCEP
# 2411                           Brain Malformations VCEP
# 2889  Hereditary Breast, Ovarian and Pancreatic Canc...
# 2890  Hereditary Breast, Ovarian and Pancreatic Canc...
# 3027                                        ACADVL VCEP
# 3112                            Monogenic Diabetes VCEP
# 3121                            Monogenic Diabetes VCEP
# 3153                 Familial Hypercholesterolemia VCEP
# 3424                        Mitochondrial Diseases VCEP
# 3603         Malignant Hyperthermia Susceptibility VCEP
# 3744                                        ACADVL VCEP
# 3852        Cerebral Creatine Deficiency Syndromes VCEP
# 3855        Cerebral Creatine Deficiency Syndromes VCEP
# 3859        Cerebral Creatine Deficiency Syndromes VCEP
# 3949                            Platelet Disorders VCEP
# 4349  InSiGHT Hereditary Colorectal Cancer/Polyposis...
# 4350  InSiGHT Hereditary Colorectal Cancer/Polyposis...
# 4351  InSiGHT Hereditary Colorectal Cancer/Polyposis...
# 4543                 Familial Hypercholesterolemia VCEP
# 4554                 Familial Hypercholesterolemia VCEP
# 4556                 Familial Hypercholesterolemia VCEP
# You can modify the `annotate_variants_list_to_dataframe` arguments to further improve the result.

# %%
annotations = gnb.annotate_variants_list_to_dataframe(erepo_subset['variant'].tolist(), flatten_consequences=True, endpoint_url=f"{host}/cloud/api-public/v1/variants")
annotations.columns
# Out:
# WARNING:root:you will log in ps209497@gmail.com
#   0%|          | 0/57 [00:00<?, ?it/s]
# 100%|██████████| 57/57 [00:29<00:00,  1.95it/s]
# Index(['chr', 'pos', 'ref', 'alt', 'transcript', 'gene_symbol', 'dbsnp',
#        'gnomad_exomes_af', 'gnomad_exomes_ac', 'gnomad_exomes_homalt',
#        'revel_score', 'bayesdelnoaf_score', 'phylop100way_score', 'acmg_score',
#        'acmg_classification', 'acmg_criteria', 'gene_hgnc_id', 'hgvs_c',
#        'consequences', 'gnomad_genomes_af', 'gnomad_genomes_ac',
#        'gnomad_genomes_homalt', 'dbscsnv_ada_score', 'alphamissense_score',
#        'apogee2_score', 'gnomad_mito_homoplasmic', 'gnomad_mito_heteroplasmic',
#        'mitotip_score'],
#       dtype='object')

# %% [markdown]
# ## Concatenate with sources
#
# Now, let's concatenate our annotations with the source database for further analysis.
#
# We will select only columns that we need for this analysis.

# %%
result = pd.concat([erepo_subset, annotations], axis=1)
result = result[['#Variation','variant','Applied Evidence Codes (Met)','acmg_criteria','acmg_score']]
result.columns
# Out:
# Index(['#Variation', 'variant', 'Applied Evidence Codes (Met)',
#        'acmg_criteria', 'acmg_score'],
#       dtype='object')

# %% [markdown]
# ## Analysis
# Here, we will analyze how the Evidence Repository ACMG criteria compare with GeneBe criteria assignments.
#
# Let's prepare the dataframe.

# %%
value_map = {'_Stand Alone':8,'_Stand alone':8,'_Stand_Alone':8, '_Stand_alone':8,'_Stand_Alone':8,  '_Very Strong': 8, '_Very_Strong': 8, '_Strong': 4, '_Moderate': 2, '_Supporting': 1, '': -1, 'None': 0}

criteria = ['PVS1', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5', 'PM1', 'PM2', 'PM3', 'PM4', 'PM5', 'PM6', 'PM7', 'PP1', 'PP2', 'PP3', 'PP4', 'PP5', 'PP6', 'BS1', 'BS2', 'BS3', 'BS4', 'BS5', 'BP1', 'BP2', 'BP3', 'BP4', 'BP5', 'BP6', 'BP7', 'BP8', 'BA1']

default_values = {        'PS1': 4,        'PS2': 4,        'PS3': 4,        'PS4': 4,        'PS5': 4,        'PM1': 2,        'PM2': 2,        'PM3': 2,        'PM4': 2,        'PM5': 2,        'PM6': 2,        'PM7': 2,        'PP1': 1,        'PP2': 1,        'PP3': 1,        'PP4': 1,        'PP5': 1,        'PP6': 1,        'BS1': 4,        'BS2': 4,        'BS3': 4,        'BS4': 4,        'BS5': 4,        'BP1': 1,    'BP2': 1,    'BP3': 1,    'BP4': 1,    'BP5': 1,    'BP6': 1,    'BP7': 1,    'BP8': 1,    'PVS1': 8,    'BA1': 8}

# if criteria contains key-criterium, in the column set number according to custom strength
for criterium in criteria:
    key = criterium + '_erepo'
    result[key] = result['Applied Evidence Codes (Met)'].str.extract(f'{criterium}([A-Za-z _]*)', expand=False).fillna('None')
    result[key] = result[key].map(value_map)

for criterium in criteria:
    key = criterium + '_genebe'
    result[key] = result['acmg_criteria'].str.extract(f'{criterium}([A-Za-z _]*)', expand=False).fillna('None')
    result[key] = result[key].map(value_map)

# set numeric values for criteria without custom strength
for criterium in criteria:
    result[criterium+'_erepo'] = result[criterium+'_erepo'].replace(-1, default_values[criterium])
    result[criterium+'_genebe'] = result[criterium+'_genebe'].replace(-1, default_values[criterium])


for suffix in '_erepo', '_genebe':
    result['score'+suffix] = (
            result['PVS1'+suffix] +
            result['PS1'+suffix] + result['PS2'+suffix] + result['PS3'+suffix] + result['PS4'+suffix] + result['PS5'+suffix] +
            result['PM1'+suffix] + result['PM2'+suffix] + result['PM3'+suffix] + result['PM4'+suffix] + result['PM5'+suffix] +
            result['PM6'+suffix] + result['PM7'+suffix] +
            result['PP1'+suffix] + result['PP2'+suffix] + result['PP3'+suffix] + result['PP4'+suffix] + result['PP5'+suffix] +
            result['PP6'+suffix]
            - result['BS1'+suffix] - result['BS2'+suffix] - result['BS3'+suffix] - result['BS4'+suffix] - result['BS5'+suffix]
            - result['BP1'+suffix] - result['BP2'+suffix] - result['BP3'+suffix] - result['BP4'+suffix] - result['BP5'+suffix]
            - result['BP6'+suffix] - result['BP7'+suffix] - result['BP8'+suffix]
            - result['BA1'+suffix]
    )

# %% [markdown]
# ## Correlation between scores
#
# When considering this correlation, remember that the human judge has access to more criteria than the GeneBe algorithm.

# %%
import numpy as np

correlation_coefficient = np.corrcoef(result['score_erepo'], result['score_genebe'])
correlation_coefficient[0,1]
# Out:
# 0.8296581587167354

# %% [markdown]
# ## Score per criterium
#
# Here, let's examine what Cohen's Kappa score looks like for each criterion when comparing ClinGen with GeneBe.
#
# Keep in mind that a score of 0 means that this criterion is not set by GeneBe due to a lack of data.

# %%
from sklearn.metrics import cohen_kappa_score
import math

kappas = {}

for criterium in criteria:
    ekey = criterium + '_erepo'
    gkey = criterium + '_genebe'
    evalues = result[ekey]
    gvalues = result[gkey]
    kappa = cohen_kappa_score(evalues, gvalues)
    if not math.isnan(kappa):
        kappas[criterium] = kappa

kappas
# Out:
# {'PVS1': 0.8185191273065793,
#  'PS1': 0.08463506882443095,
#  'PS2': 0.0,
#  'PS3': 0.0,
#  'PS4': 0.0,
#  'PM1': 0.19009215930803292,
#  'PM2': 0.3822234354548125,
#  'PM3': 0.0,
#  'PM4': 0.5092724302972851,
#  'PM5': 0.22769678423922513,
#  'PM6': 0.0,
#  'PP1': 0.0,
#  'PP2': 0.298912072811791,
#  'PP3': 0.25917740782891785,
#  'PP4': 0.0,
#  'PP5': 0.0,
#  'BS1': 0.0918472799703457,
#  'BS2': 0.20740807822023832,
#  'BS3': 0.0,
#  'BS4': 0.0,
#  'BP1': 0.0,
#  'BP2': 0.0,
#  'BP3': 0.0,
#  'BP4': 0.2193168963734642,
#  'BP5': 0.0,
#  'BP6': 0.0,
#  'BP7': 0.5930384471817842,
#  'BA1': 0.3726553632392755}
